# %% [markdown]
# # Feature Engineering V2

# %% [markdown]
# ## Volatility
# - ATR5
# - std5
# - norm_tr
# - vol_ratio_5
#
# ## Momentum
# - ROC2
# - ROC3
# - ROC5
# - RSI7
#
# ## Trend Direction
# - MA5
# - MA10
# - Close/MA5 ratio
#
# ## Candle Structure
# - candle_body_pct
#
# ## Volume
# - vol_ma5
# - vol_spike_5
#
# ## Lagged Returns
# - return_1d
# - return_2d
# - return_3d
#
# ## Target
# - target (3-day direction)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option("display.max_columns", None)

# Load cleaned historical data
df = pd.read_csv("C:/Users/USER/Documents/QQQ Project/data/processed/new_QQQ_data.csv",
                 parse_dates=["Date"],
                 index_col="Date")

df.head()
# Out:
#                 Open       High       Low      Close   Volume
# Date
# 1999-03-10  51.12500  51.156250  50.28125  43.478279  5232000
# 1999-03-11  51.43750  51.734375  50.31250  43.691170  9688600
# 1999-03-12  51.12500  51.156250  49.65625  42.626823  8743600
# 1999-03-15  50.43750  51.562500  49.90625  43.850815  6369000
# 1999-03-16  51.71875  52.156250  51.15625  44.223331  4905800

# %%
df["returns"] = df["Close"].pct_change()

# %% [markdown]
# ATR 5 Day

# %%
def compute_atr(df, window=5):
    high_low = df["High"] - df["Low"]
    high_close = (df["High"] - df["Close"].shift()).abs()
    low_close  = (df["Low"] - df["Close"].shift()).abs()
    tr = pd.concat([high_low, high_close, low_close], axis=1).max(axis=1)
    atr = tr.rolling(window).mean()
    return atr

df["ATR5"] = compute_atr(df, 5)

# %% [markdown]
# Rolling STD 5

# %%
df["std5"] = df["returns"].rolling(5).std()

# %% [markdown]
# Normalized True Range + vol ratio

# %%
df["norm_tr"] = (df["High"] - df["Low"]) / df["Close"]
df["vol_ratio_5"] = df["ATR5"] / df["std5"]

# %% [markdown]
# Momentum ROC 2,3,5 AND RSI 7

# %%
# ROC2, ROC3, ROC5
df["roc2"] = df["Close"].pct_change(2)
df["roc3"] = df["Close"].pct_change(3)
df["roc5"] = df["Close"].pct_change(5)

# RSI7
def compute_rsi(series, window=7):
    delta = series.diff()
    gain = delta.clip(lower=0).rolling(window).mean()
    loss = (-delta).clip(lower=0).rolling(window).mean()
    rs = gain / loss
    return 100 - (100 / (1 + rs))

df["rsi7"] = compute_rsi(df["Close"], 7)

# %% [markdown]
# Trend MA 5 , MA 10, Close MA5

# %%
df["MA5"] = df["Close"].rolling(5).mean()
df["MA10"] = df["Close"].rolling(10).mean()
df["close_ma5_ratio"] = df["Close"] / df["MA5"]

# %% [markdown]
# Candle Structure Feature

# %%
df["candle_body_pct"] = (
    (df["Close"] - df["Open"]).abs() /
    (df["High"] - df["Low"]).replace(0, np.nan)
).fillna(0)

# %% [markdown]
# Volume Features 5day

# %%
df["vol_ma5"] = df["Volume"].rolling(5).mean()
df["vol_spike_5"] = df["Volume"] / df["vol_ma5"]

# %% [markdown]
# Lagged Returns

# %%
df["return_1d"] = df["Close"].pct_change(1)
df["return_2d"] = df["Close"].pct_change(2)
df["return_3d"] = df["Close"].pct_change(3)

# %% [markdown]
# Target (3-Day Direction)

# %%
df["future_3d_return"] = df["Close"].shift(-3) / df["Close"] - 1
df["target"] = (df["future_3d_return"] > 0).astype(int)

# %%
df_clean = df.dropna().copy()
df_clean.head()
# Out:
#                Open      High        Low      Close    Volume   returns  \
# Date
# 1999-03-23  50.3125  50.50000  48.718750  41.562469  10962400 -0.035207
# 1999-03-24  49.2500  50.50000  48.500000  42.972725   8447000  0.033931
# 1999-03-25  51.2500  52.31250  50.914062  44.542622   8133800  0.036532
# 1999-03-26  51.8750  52.46875  51.531250  44.063675   8256200 -0.010753
# 1999-03-29  52.3750  53.65625  52.062500  45.660183   5113800  0.036232
#
#                 ATR5      std5   norm_tr  vol_ratio_5      roc2      roc3  \
# Date
# 1999-03-23  8.066575  0.020802  0.042857   387.772095 -0.046980 -0.071344
# 1999-03-24  8.298747  0.029548  0.046541   280.859638 -0.002471 -0.014643
# 1999-03-25  8.428757  0.033640  0.031395   250.554871  0.071703  0.033971
# 1999-03-26  8.315086  0.031463  0.021276   264.279574  0.025387  0.060179
# 1999-03-29  8.643367  0.033227  0.034905   260.131978  0.025090  0.062539
#
#                 roc5       rsi7        MA5       MA10  close_ma5_ratio  \
# Date
# 1999-03-23 -0.060169  41.071369  43.382503  43.478293         0.958047
# 1999-03-24 -0.021212  42.857116  43.196243  43.427738         0.994826
# 1999-03-25 -0.004757  52.173820  43.153664  43.512883         1.032186
# 1999-03-26  0.010372  51.063811  43.244133  43.656568         1.018952
# 1999-03-29  0.059913  55.483750  43.760335  43.837505         1.043415
#
#             candle_body_pct    vol_ma5  vol_spike_5  return_1d  return_2d  \
# Date
# 1999-03-23         4.912298  6392200.0     1.714965  -0.035207  -0.046980
# 1999-03-24         3.138638  7288600.0     1.158933   0.033931  -0.002471
# 1999-03-25         4.796338  7945680.0     1.023676   0.036532   0.071703
# 1999-03-26         8.332080  8164840.0     1.011189  -0.010753   0.025387
# 1999-03-29         4.213219  8182640.0     0.624957   0.036232   0.025090
#
#             return_3d  future_3d_return  target
# Date
# 1999-03-23  -0.071344          0.060179       1
# 1999-03-24  -0.014643          0.062539       1
# 1999-03-25   0.033971          0.017921       1
# 1999-03-26   0.060179          0.013889       1
# 1999-03-29   0.062539         -0.001165       0

# %%
final_features = [
    "ATR5", "std5", "norm_tr", "vol_ratio_5",
    "roc2", "roc3", "roc5", "rsi7",
    "MA5", "MA10", "close_ma5_ratio",
    "candle_body_pct",
    "vol_ma5", "vol_spike_5",
    "return_1d", "return_2d", "return_3d",
    "target"
]

df_final = df_clean[final_features].copy()
df_final.to_csv("C:/Users/USER/Documents/QQQ Project/data/processed/qqq_features_classificationv2.csv")

df_final.head()
# Out:
#                 ATR5      std5   norm_tr  vol_ratio_5      roc2      roc3  \
# Date
# 1999-03-23  8.066575  0.020802  0.042857   387.772095 -0.046980 -0.071344
# 1999-03-24  8.298747  0.029548  0.046541   280.859638 -0.002471 -0.014643
# 1999-03-25  8.428757  0.033640  0.031395   250.554871  0.071703  0.033971
# 1999-03-26  8.315086  0.031463  0.021276   264.279574  0.025387  0.060179
# 1999-03-29  8.643367  0.033227  0.034905   260.131978  0.025090  0.062539
#
#                 roc5       rsi7        MA5       MA10  close_ma5_ratio  \
# Date
# 1999-03-23 -0.060169  41.071369  43.382503  43.478293         0.958047
# 1999-03-24 -0.021212  42.857116  43.196243  43.427738         0.994826
# 1999-03-25 -0.004757  52.173820  43.153664  43.512883         1.032186
# 1999-03-26  0.010372  51.063811  43.244133  43.656568         1.018952
# 1999-03-29  0.059913  55.483750  43.760335  43.837505         1.043415
#
#             candle_body_pct    vol_ma5  vol_spike_5  return_1d  return_2d  \
# Date
# 1999-03-23         4.912298  6392200.0     1.714965  -0.035207  -0.046980
# 1999-03-24         3.138638  7288600.0     1.158933   0.033931  -0.002471
# 1999-03-25         4.796338  7945680.0     1.023676   0.036532   0.071703
# 1999-03-26         8.332080  8164840.0     1.011189  -0.010753   0.025387
# 1999-03-29         4.213219  8182640.0     0.624957   0.036232   0.025090
#
#             return_3d  target
# Date
# 1999-03-23  -0.071344       1
# 1999-03-24  -0.014643       1
# 1999-03-25   0.033971       1
# 1999-03-26   0.060179       1
# 1999-03-29   0.062539       0
